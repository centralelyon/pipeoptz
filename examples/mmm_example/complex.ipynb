# %% [markdown]
# # Optimizing a Complex Pipeline
#
# This notebook showcases a more advanced use of `pipeoptz` for a background removal task.
#
# It introduces:
# - A bigger pipeline with more parameters to optimize
# - A custom loss function (Intersection over Union).
# - Different parameter types like `BoolParameter`.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from math import comb
from sklearn.cluster import KMeans
from skimage.color import rgb2lab, lab2rgb
import scipy as sp
from PIL import Image
import sys, os, time
sys.path.append(os.path.abspath("../../"))
from pipeoptz import Pipeline, Node, PipelineOptimizer, BoolParameter, IntParameter

# %% [markdown]
# ## Pipeline Components
#
# First, we define the basic building blocks: the functions that will serve as nodes in our pipeline and a custom loss function to evaluate the results.

# %%
def ith_subset(n, i):
    total = 2**n
    if i < 0 or i >= total:
        raise ValueError(f"Index i must be in [0, {total - 1}]")

    remaining = i
    for k in range(n + 1):
        c = comb(n, k)
        if remaining < c:
            cardinality = k
            break
        remaining -= c

    subset = []
    x = 0
    for j in range(cardinality):
        while comb(n-1 - x, cardinality - j - 1) <= remaining:
            remaining -= comb(n-1 - x, cardinality - j - 1)
            x += 1
        subset.append(x)
        x += 1
    return subset

def integer(n):
    return n

def to_mask(image):
    return image[:,:,3] != 0

def biggest_mask(elements):
    size = []
    if len(elements) != 0:
        for el in elements:
            size.append(el.sum())
        return elements[size.index(max(size))]
    else:
        return None

def colored_mask(image, mask):
    if mask is not None:
        return image*mask[:,:,np.newaxis]
    else:
        return np.zeros(shape=image.shape)

def extract_palette(image, n_colors, sample_size=0, max_iter=300, use_lab=False):
    if image.shape[2] == 4:
        opaque_mask = image[:, :, 3] != 0
        pixels = image[opaque_mask][:, :3]
        if pixels.shape[0] == 0:
            return np.array([], dtype=np.uint8).reshape(0, 3)
    elif image.shape[2] == 3:  # RGB
        pixels = image.reshape(-1, 3)
    else:
        raise ValueError("Image must be RGB or RGBA.")
    
    if use_lab:
        pixels_normalized = pixels.astype(np.float32) / 255.0
        data_for_kmeans = rgb2lab(pixels_normalized)
    else:
        data_for_kmeans = pixels.astype(np.float32)

    if sample_size > 0 and data_for_kmeans.shape[0] > sample_size:
        indices = np.random.choice(data_for_kmeans.shape[0], size=sample_size, replace=False)
        sample = data_for_kmeans[indices]
    else:
        sample = data_for_kmeans

    if sample.shape[0] < n_colors:
        n_colors = max(1, sample.shape[0])
        if n_colors == 0:
            return np.array([], dtype=np.uint8).reshape(0, 3)

    kmeans = KMeans(n_clusters=n_colors, max_iter=max_iter, n_init='auto', random_state=0)
    kmeans.fit(sample)
    centers = kmeans.cluster_centers_

    if use_lab:
        palette_float = lab2rgb(centers)
        palette = np.clip(palette_float * 255, 0, 255).astype(np.uint8)
        l_values = centers[:, 0]
        sorted_indices = np.argsort(l_values)[::-1]
        palette = palette[sorted_indices]
    else:
        palette_float = centers
        palette = np.clip(palette_float, 0, 255).astype(np.uint8)
        luminance = 0.299 * palette[:, 0] + 0.587 * palette[:, 1] + 0.114 * palette[:, 2]
        sorted_indices = np.argsort(luminance)[::-1]
        palette = palette[sorted_indices]
        
    return palette

def recolor(image, palette) :
    h, w, c = image.shape
    is_rgba = (c == 4)
    
    rgb_image_part = image[:, :, :3].astype(np.float32)
    pixels_flat = rgb_image_part.reshape(-1, 3)
    palette_float = palette.astype(np.float32)

    dists = np.linalg.norm(pixels_flat[:, np.newaxis, :] - palette_float[np.newaxis, :, :], axis=2)
    
    nearest_palette_indices = np.argmin(dists, axis=1)
    recolored_rgb_flat = palette[nearest_palette_indices]
    recolored_rgb = recolored_rgb_flat.reshape(h, w, 3).astype(np.uint8)

    if is_rgba:
        alpha_channel = image[:, :, 3:]
        return np.dstack((recolored_rgb, alpha_channel))
    return recolored_rgb

def remove_palette(image, recolored_image, palette, indices_to_remove):
    if image.shape[2] != 4:
        raise ValueError("Original image must be RGBA.")

    output_image = image.copy()
    recolored_rgb = recolored_image[:,:,:3]

    for i in indices_to_remove:
        if 0 <= i < len(palette):
            color_to_match = palette[i]
            match_mask = np.all(recolored_rgb == color_to_match, axis=2)
            output_image[match_mask, 3] = 0
    return output_image

def isolate(binary_mask, sizemin=1):
    if not np.any(binary_mask):
        return []
    labeled_array, num_features = sp.ndimage.label(binary_mask)
    
    elements = []
    for i in range(1, num_features + 1):
        component_mask = (labeled_array == i)
        if np.sum(component_mask) >= sizemin:
            elements.append(component_mask)
    return elements

def detect_edges(image, threshold1, threshold2, activate=True):
    if not activate:
        return np.zeros(shape=image.shape[:2])
    if image.ndim == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image.copy()
    edges = cv2.Canny(gray, threshold1, threshold2)
    return edges

def union(f1, f2):
    return np.bool(f1)|np.bool(f2)

# %% [markdown]
# Definition of IoU and a loss function using it

# %%
def IoU(im1, im2):
    f1 = im1[:,:,3]==255
    f2 = im2[:,:,3]==255
    intersection = (f1 & f2).sum()
    union = (f1 | f2).sum()
    return intersection / union if union > 0 else 0

def loss(f1, f2):
    return 1/(IoU(f1, f2)+1e-20)**2

# %% [markdown]
# ## Pipeline Definition & Optimizer Setup
#
# Now, we assemble the functions into a complex, non-linear pipeline and set up the optimizer's search space. Note the use of various parameter types like `IntParameter` and `BoolParameter`.

# %%
pipeline = Pipeline("RemoveBG")

pipeline.add_node(Node("Palette size", integer, fixed_params={"n":8}))
pipeline.add_node(Node("Extract palette", extract_palette, fixed_params={"use_lab":False}), predecessors={"image":"run_params:image", "n_colors":"Palette size"})
pipeline.add_node(Node("Palette indices", ith_subset, fixed_params={"i": 37}), predecessors={"n":"Palette size"})
pipeline.add_node(Node("Recolor", recolor), predecessors={"image":"run_params:image", "palette":"Extract palette"})
pipeline.add_node(Node("Remove palette", remove_palette), predecessors={"image":"run_params:image", "recolored_image":"Recolor", "palette":"Extract palette", "indices_to_remove":"Palette indices"})
pipeline.add_node(Node('Edge detection 2', detect_edges, fixed_params={"threshold1":100, "threshold2":100, "activate":True}), predecessors={"image":"run_params:image"})
pipeline.add_node(Node('Edge detection 1', detect_edges, fixed_params={"threshold1":100, "threshold2":100, "activate":True}), predecessors={"image":"Recolor"})
pipeline.add_node(Node("Edge union", union), predecessors={"f1":"Edge detection 1", "f2":"Edge detection 2"})
pipeline.add_node(Node("Final union", union), predecessors={"f1":"Edge union", "f2":"To mask"})
pipeline.add_node(Node("To mask", to_mask), predecessors={"image":"Remove palette"})
pipeline.add_node(Node("Isolate", isolate), predecessors={"binary_mask": "Final union"})
pipeline.add_node(Node("Main element", biggest_mask), predecessors={"elements":"Isolate"})
pipeline.add_node(Node("Colored element", colored_mask), predecessors={"image":"run_params:image", "mask":"Main element"})

pipeline.to_dot(generate_png=True, cleanup_dot=True)
im = np.array(Image.open("RemoveBG.png"))
plt.axis('off')
plt.imshow(im)

# %%
optimizer = PipelineOptimizer(pipeline, loss, max_time_pipeline=0.1)
optimizer.add_param(IntParameter("Palette size", "n", 8, 15))
optimizer.add_param(IntParameter("Palette indices", "i", 1, 63))
optimizer.add_param(BoolParameter("Extract palette", "use_lab"))
optimizer.add_param(IntParameter("Edge detection 1", "threshold1", 0, 255))
optimizer.add_param(IntParameter("Edge detection 1", "threshold2", 0, 255))
optimizer.add_param(BoolParameter("Edge detection 1", "activate"))
optimizer.add_param(IntParameter("Edge detection 2", "threshold1", 0, 255))
optimizer.add_param(IntParameter("Edge detection 2", "threshold2", 0, 255))
optimizer.add_param(BoolParameter("Edge detection 2", "activate"))

# %% [markdown]
# ## Running & Comparing Optimizers
#
# We run several optimization algorithms and record their performance and execution time.

# %% [markdown]
# ### Lolipop Dataset

# %%
X = []
y = []
for i in range(5):
    X.append({"image":np.array(Image.open(f"images/lolipop/{i}.png"))})
    y.append(np.array(Image.open(f"images/lolipop/edited/{i}.png")))

# %%
params_and_log = {}
times = {}
methods = {"ACO":{"iterations":10, "ants":15},
           "SA":{"iterations":50}, 
           "PSO":{"iterations":10, "swarm_size":10}, 
           "GA":{"generations":10, "population_size":15}, 
           "GS":{"max_combinations":100}, 
           "BO":{"iterations":25, "init_points":25}}

for i, method in enumerate(methods):
    t = time.time()
    print(f"Method {method} :")
    params_and_log[method] = optimizer.optimize(X, y, method=method, verbose=True, **methods[method])
    times[method] = time.time()-t
    print()
# Out:
# Method ACO :
# Iteration 10/10
# Method SA :
# Iteration 50/50
# Method PSO :
# Iteration 10/10
# Method GA :
# Generation 10/10
# Method GS :
# Iteration 100/100
# Method BO :
# Iteration 25/25

# %% [markdown]
# Finally, we visualize the loss curves for each method and compare their final segmentation masks.

# %%
plt.figure(figsize=(7, 25))
plt.subplot(7, 2, 1)
plt.axis('off')
plt.imshow(X[0]["image"])
plt.subplot(7, 2, 2)
plt.axis('off')
plt.imshow(y[0])

ims = []
for i, method in enumerate(methods):
    pipeline.set_fixed_params(params_and_log[method][0])
    print(pipeline.get_fixed_params())
    ind, hist, _ = pipeline.run(X[0])
    ims.append(hist[ind])
    
    plt.subplot(7, 2, 3+2*i)
    plt.gca().set_yscale('log')
    plt.title(method)
    plt.plot(params_and_log[method][1])

    plt.subplot(7, 2, 4+2*i)
    plt.axis('off')
    plt.title(f"Time: {times[method]:.2f}s")
    plt.imshow(ims[-1], cmap="gray", vmin=0, vmax=255)
# Out:
# {'Palette size.n': np.int64(9), 'Extract palette.use_lab': np.False_, 'Palette indices.i': np.int64(49), 'Edge detection 2.threshold1': np.int64(101), 'Edge detection 2.threshold2': np.int64(210), 'Edge detection 2.activate': np.False_, 'Edge detection 1.threshold1': np.int64(58), 'Edge detection 1.threshold2': np.int64(21), 'Edge detection 1.activate': np.True_}
# {'Palette size.n': 9, 'Extract palette.use_lab': True, 'Palette indices.i': 55, 'Edge detection 2.threshold1': 72, 'Edge detection 2.threshold2': 119, 'Edge detection 2.activate': True, 'Edge detection 1.threshold1': 145, 'Edge detection 1.threshold2': 142, 'Edge detection 1.activate': True}
# {'Palette size.n': 14, 'Extract palette.use_lab': False, 'Palette indices.i': 15, 'Edge detection 2.threshold1': 157, 'Edge detection 2.threshold2': 235, 'Edge detection 2.activate': False, 'Edge detection 1.threshold1': 31, 'Edge detection 1.threshold2': 99, 'Edge detection 1.activate': False}
# {'Palette size.n': 9, 'Extract palette.use_lab': True, 'Palette indices.i': 46, 'Edge detection 2.threshold1': 83, 'Edge detection 2.threshold2': 3, 'Edge detection 2.activate': True, 'Edge detection 1.threshold1': 75, 'Edge detection 1.threshold2': 18, 'Edge detection 1.activate': True}
# {'Palette size.n': 12, 'Extract palette.use_lab': True, 'Palette indices.i': 14, 'Edge detection 2.threshold1': 30, 'Edge detection 2.threshold2': 13, 'Edge detection 2.activate': True, 'Edge detection 1.threshold1': 155, 'Edge detection 1.threshold2': 199, 'Edge detection 1.activate': False}
# {'Palette size.n': 10, 'Extract palette.use_lab': True, 'Palette indices.i': 63, 'Edge detection 2.threshold1': 128, 'Edge detection 2.threshold2': 249, 'Edge detection 2.activate': True, 'Edge detection 1.threshold1': 175, 'Edge detection 1.threshold2': 25, 'Edge detection 1.activate': True}

# %%
n = 62
plt.figure(figsize=(20, 10))
for i in range(n):
    print(f"{i+1}/{n}", end="\t\r")
    plt.subplot(n//12+1, 12, i+1)
    im = np.array(Image.open(f"images/lolipop/{i}.png"))
    res = pipeline.run({"image":im})
    plt.axis('off')
    plt.imshow(res[1][res[0]])
# Out:
# 62/62

# %% [markdown]
# ### Goodbye Dataset

# %%
X2 = []
y2 = []
for i in range(5):
    X2.append({"image":np.array(Image.open(f"images/goodbye/{i}.png"))})
    y2.append(np.array(Image.open(f"images/goodbye/edited/{i}.png")))

# %%
params_and_log2 = {}
times2 = {}
methods2 = {"ACO":{"iterations":10, "ants":20},
            "SA":{"iterations":100}, 
            "PSO":{"iterations":10, "swarm_size":15}, 
            "GA":{"generations":15, "population_size":20}, 
            "GS":{"max_combinations":250}, 
            "BO":{"iterations":40, "init_points":25}}

for i, method in enumerate(methods2):
    t = time.time()
    print(f"Method {method} :")
    params_and_log2[method] = optimizer.optimize(X, y, method=method, verbose=True, **methods2[method])
    times2[method] = time.time()-t
    print()
# Out:
# Method ACO :
# Iteration 10/10
# Method SA :
# Iteration 100/100
# Method PSO :
# Iteration 10/10
# Method GA :
# Generation 15/15
# Method GS :
# Iteration 250/250
# Method BO :
# Iteration 40/40

# %%
plt.figure(figsize=(7,25))
plt.subplot(7, 2, 1)
plt.axis('off')
plt.imshow(X2[0]["image"])
plt.subplot(7, 2, 2)
plt.axis('off')
plt.imshow(y2[0])

ims2 = []
for i, method in enumerate(methods2):
    pipeline.set_fixed_params(params_and_log2[method][0])
    print(pipeline.get_fixed_params())
    ind, hist, _ = pipeline.run(X2[0])
    ims2.append(hist[ind])
    
    plt.subplot(7, 2, 3+2*i)
    plt.gca().set_yscale('log')
    plt.title(method)
    plt.plot(params_and_log2[method][1])

    plt.subplot(7, 2, 4+2*i)
    plt.axis('off')
    plt.title(f"Time: {times2[method]:.2f}s")
    plt.imshow(ims2[-1], cmap="gray", vmin=0, vmax=255)
# Out:
# {'Palette size.n': np.int64(10), 'Extract palette.use_lab': np.True_, 'Palette indices.i': np.int64(56), 'Edge detection 2.threshold1': np.int64(63), 'Edge detection 2.threshold2': np.int64(40), 'Edge detection 2.activate': np.True_, 'Edge detection 1.threshold1': np.int64(180), 'Edge detection 1.threshold2': np.int64(32), 'Edge detection 1.activate': np.False_}
# {'Palette size.n': 9, 'Extract palette.use_lab': True, 'Palette indices.i': 46, 'Edge detection 2.threshold1': 112, 'Edge detection 2.threshold2': 15, 'Edge detection 2.activate': True, 'Edge detection 1.threshold1': 251, 'Edge detection 1.threshold2': 237, 'Edge detection 1.activate': True}
# {'Palette size.n': 10, 'Extract palette.use_lab': False, 'Palette indices.i': 56, 'Edge detection 2.threshold1': 106, 'Edge detection 2.threshold2': 132, 'Edge detection 2.activate': True, 'Edge detection 1.threshold1': 29, 'Edge detection 1.threshold2': 219, 'Edge detection 1.activate': True}
# {'Palette size.n': 8, 'Extract palette.use_lab': True, 'Palette indices.i': 10, 'Edge detection 2.threshold1': 95, 'Edge detection 2.threshold2': 56, 'Edge detection 2.activate': True, 'Edge detection 1.threshold1': 203, 'Edge detection 1.threshold2': 106, 'Edge detection 1.activate': False}
# {'Palette size.n': 11, 'Extract palette.use_lab': True, 'Palette indices.i': 13, 'Edge detection 2.threshold1': 64, 'Edge detection 2.threshold2': 79, 'Edge detection 2.activate': False, 'Edge detection 1.threshold1': 37, 'Edge detection 1.threshold2': 153, 'Edge detection 1.activate': False}
# {'Palette size.n': 13, 'Extract palette.use_lab': False, 'Palette indices.i': 14, 'Edge detection 2.threshold1': 88, 'Edge detection 2.threshold2': 115, 'Edge detection 2.activate': False, 'Edge detection 1.threshold1': 235, 'Edge detection 1.threshold2': 182, 'Edge detection 1.activate': False}

# %%
n = 75
plt.figure(figsize=(15, 8))
for i in range(n):
    print(f"{i+1}/{n}", end="\t\r")
    plt.subplot(n//12+1, 12, i+1)
    im = np.array(Image.open(f"images/goodbye/{i}.png"))
    res = pipeline.run({"image":im})
    plt.axis('off')
    plt.imshow(res[1][res[0]])
# Out:
# 75/75
